# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading in deer harvest reports individually by year. Will need to add a 'year' column before merging data into one df.

# %%
harvest_2013 = pd.read_csv("../Data\deer_harvest_report_2013.csv")
harvest_2014 = pd.read_csv("../Data\deer_harvest_report_2014.csv")
harvest_2015 = pd.read_csv("../Data\deer_harvest_report_2015.csv")
harvest_2016 = pd.read_csv("../Data\deer_harvest_report_2016.csv")
harvest_2017 = pd.read_csv("../Data\deer_harvest_report_2017.csv")
harvest_2018 = pd.read_csv("../Data\deer_harvest_report_2018.csv")
harvest_2019 = pd.read_csv("../Data\deer_harvest_report_2019.csv")
harvest_2020 = pd.read_csv("../Data\deer_harvest_report_2020.csv")
harvest_2021 = pd.read_csv("../Data\deer_harvest_report_2021.csv")
harvest_2022 = pd.read_csv("../Data\deer_harvest_report_2022.csv")
harvest_2023 = pd.read_csv("../Data\deer_harvest_report_2023.csv")

# %%
harvest_2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Textbox1           95 non-null     object
#  1   AreaType           95 non-null     object
#  2   AntlerMaleCnt      95 non-null     int64
#  3   AntlerlessMaleCnt  95 non-null     int64
#  4   FemaleCnt          95 non-null     object
#  5   TotalHarvestCount  95 non-null     object
#  6   Textbox4           95 non-null     int64
#  7   Textbox6           95 non-null     object
#  8   Textbox7           95 non-null     object
#  9   Textbox8           95 non-null     object
# dtypes: int64(3), object(7)
# memory usage: 7.6+ KB

# %%
harvest_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Textbox1           95 non-null     object
#  1   AreaType           95 non-null     object
#  2   AntlerMaleCnt      95 non-null     object
#  3   AntlerlessMaleCnt  95 non-null     int64
#  4   FemaleCnt          95 non-null     object
#  5   TotalHarvestCount  95 non-null     object
#  6   Textbox4           95 non-null     object
#  7   Textbox6           95 non-null     object
#  8   Textbox7           95 non-null     object
#  9   Textbox8           95 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 7.6+ KB

# %%
harvest_2013.head()
# Out:
#   Textbox1  AreaType  AntlerMaleCnt  AntlerlessMaleCnt FemaleCnt  \
# 0   County  Anderson              0                 58       496
# 1   County   Bedford              0                 74       930
# 2   County    Benton              0                167     1,118
# 3   County   Bledsoe              0                 91       444
# 4   County    Blount              0                 29       237
#
#   TotalHarvestCount  Textbox4 Textbox6 Textbox7 Textbox8
# 0             1,112         1    8,558   73,906  168,522
# 1             2,021         1    8,558   73,906  168,522
# 2             2,368         1    8,558   73,906  168,522
# 3             1,054         1    8,558   73,906  168,522
# 4               687         1    8,558   73,906  168,522

# %%
harvest_2023.head()
# Out:
#   Textbox1  AreaType AntlerMaleCnt  AntlerlessMaleCnt FemaleCnt  \
# 0   County  Anderson           545                 44       338
# 1   County   Bedford         1,079                 66       718
# 2   County    Benton           773                 94       590
# 3   County   Bledsoe           723                 36       409
# 4   County    Blount           602                 27       216
#
#   TotalHarvestCount Textbox4 Textbox6 Textbox7 Textbox8
# 0               931   84,433    7,163   60,550  152,875
# 1             1,871   84,433    7,163   60,550  152,875
# 2             1,458   84,433    7,163   60,550  152,875
# 3             1,173   84,433    7,163   60,550  152,875
# 4               852   84,433    7,163   60,550  152,875

# %% [markdown]
# ## Need to remove Textbox1, Textbox4, Textbox6, Textbox7, and Textbox8 columns. They are grand totals for the entire data set but not needed. Also need to rename 'AreaType' to 'County'

# %%
#testing on 2013 data.
harvest_2013 = harvest_2013.drop(columns=['Textbox1', 'Textbox4', 'Textbox6', 'Textbox7', 'Textbox8'])
harvest_2013 = harvest_2013.rename(columns={'AreaType': 'County'})

# %%
harvest_2013.head()
# Out:
#      County  AntlerMaleCnt  AntlerlessMaleCnt FemaleCnt TotalHarvestCount
# 0  Anderson              0                 58       496             1,112
# 1   Bedford              0                 74       930             2,021
# 2    Benton              0                167     1,118             2,368
# 3   Bledsoe              0                 91       444             1,054
# 4    Blount              0                 29       237               687

# %%
#repeating process above for rest of harvest files.
harvest_2014 = harvest_2014.drop(columns=['Textbox1', 'Textbox4', 'Textbox6', 'Textbox7', 'Textbox8'])
harvest_2014 = harvest_2014.rename(columns={'AreaType': 'County'})
harvest_2015 = harvest_2015.drop(columns=['Textbox1', 'Textbox4', 'Textbox6', 'Textbox7', 'Textbox8'])
harvest_2015 = harvest_2015.rename(columns={'AreaType': 'County'})
harvest_2016 = harvest_2016.drop(columns=['Textbox1', 'Textbox4', 'Textbox6', 'Textbox7', 'Textbox8'])
harvest_2016 = harvest_2016.rename(columns={'AreaType': 'County'})
harvest_2017 = harvest_2017.drop(columns=['Textbox1', 'Textbox4', 'Textbox6', 'Textbox7', 'Textbox8'])
harvest_2017 = harvest_2017.rename(columns={'AreaType': 'County'})
harvest_2018 = harvest_2018.drop(columns=['Textbox1', 'Textbox4', 'Textbox6', 'Textbox7', 'Textbox8'])
harvest_2018 = harvest_2018.rename(columns={'AreaType': 'County'})
harvest_2019 = harvest_2019.drop(columns=['Textbox1', 'Textbox4', 'Textbox6', 'Textbox7', 'Textbox8'])
harvest_2019 = harvest_2019.rename(columns={'AreaType': 'County'})
harvest_2020 = harvest_2020.drop(columns=['Textbox1', 'Textbox4', 'Textbox6', 'Textbox7', 'Textbox8'])
harvest_2020 = harvest_2020.rename(columns={'AreaType': 'County'})
harvest_2021 = harvest_2021.drop(columns=['Textbox1', 'Textbox4', 'Textbox6', 'Textbox7', 'Textbox8'])
harvest_2021 = harvest_2021.rename(columns={'AreaType': 'County'})
harvest_2022 = harvest_2022.drop(columns=['Textbox1', 'Textbox4', 'Textbox6', 'Textbox7', 'Textbox8'])
harvest_2022 = harvest_2022.rename(columns={'AreaType': 'County'})
harvest_2023 = harvest_2023.drop(columns=['Textbox1', 'Textbox4', 'Textbox6', 'Textbox7', 'Textbox8'])
harvest_2023 = harvest_2023.rename(columns={'AreaType': 'County'})

# %%
harvest_2023.head()
# Out:
#      County AntlerMaleCnt  AntlerlessMaleCnt FemaleCnt TotalHarvestCount
# 0  Anderson           545                 44       338               931
# 1   Bedford         1,079                 66       718             1,871
# 2    Benton           773                 94       590             1,458
# 3   Bledsoe           723                 36       409             1,173
# 4    Blount           602                 27       216               852

# %%
#next need to add a 'season' column with the corresponding file year.
harvest_2013['Season'] = '2013'
harvest_2013.head()
# Out:
#      County  AntlerMaleCnt  AntlerlessMaleCnt FemaleCnt TotalHarvestCount  \
# 0  Anderson              0                 58       496             1,112
# 1   Bedford              0                 74       930             2,021
# 2    Benton              0                167     1,118             2,368
# 3   Bledsoe              0                 91       444             1,054
# 4    Blount              0                 29       237               687
#
#   Season
# 0   2013
# 1   2013
# 2   2013
# 3   2013
# 4   2013

# %%
#repeat the process for the rest of the files.
harvest_2014['Season'] = '2014'
harvest_2015['Season'] = '2015'
harvest_2016['Season'] = '2016'
harvest_2017['Season'] = '2017'
harvest_2018['Season'] = '2018'
harvest_2019['Season'] = '2019'
harvest_2020['Season'] = '2020'
harvest_2021['Season'] = '2021'
harvest_2022['Season'] = '2022'
harvest_2023['Season'] = '2023'
harvest_2023.head()
# Out:
#      County AntlerMaleCnt  AntlerlessMaleCnt FemaleCnt TotalHarvestCount  \
# 0  Anderson           545                 44       338               931
# 1   Bedford         1,079                 66       718             1,871
# 2    Benton           773                 94       590             1,458
# 3   Bledsoe           723                 36       409             1,173
# 4    Blount           602                 27       216               852
#
#   Season
# 0   2023
# 1   2023
# 2   2023
# 3   2023
# 4   2023

# %% [markdown]
# ## Need to now merge the files to one file.

# %%
deer_harvest = pd.concat([harvest_2013, harvest_2014, harvest_2015, harvest_2016, harvest_2017, harvest_2018, harvest_2019, harvest_2020, harvest_2021, harvest_2022, harvest_2023])

# %%
deer_harvest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1052 entries, 0 to 94
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   County             1045 non-null   object
#  1   AntlerMaleCnt      1052 non-null   object
#  2   AntlerlessMaleCnt  1052 non-null   int64
#  3   FemaleCnt          1052 non-null   object
#  4   TotalHarvestCount  1052 non-null   object
#  5   Season             1052 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 57.5+ KB

# %%
deer_harvest.head()
# Out:
#       County  AntlerMaleCnt  AntlerlessMaleCnt  FemaleCnt  TotalHarvestCount  \
# 0   Anderson              0                 58        496               1112
# 1    Bedford              0                 74        930               2021
# 2     Benton              0                167       1118               2368
# 3    Bledsoe              0                 91        444               1054
# 4     Blount              0                 29        237                687
# ..       ...            ...                ...        ...                ...
# 54   Madison              0                169       1595               2986
# 55    Marion              0                 59        548               1533
# 56  Marshall              0                112       1183               2328
# 57     Maury              0                218       1786               3644
# 58    McMinn              0                 73        692               1622
#
#    Season
# 0    2013
# 1    2013
# ...

# %%
#removed commas to convert dtypes to int.
deer_harvest = deer_harvest.replace(',','', regex=True)

# %%
deer_harvest['AntlerMaleCnt'] = deer_harvest['AntlerMaleCnt'].astype(int)
deer_harvest['FemaleCnt'] = deer_harvest['FemaleCnt'].astype(int)
deer_harvest['TotalHarvestCount'] = deer_harvest['TotalHarvestCount'].astype(int)

# %%
deer_harvest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1052 entries, 0 to 94
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   County             1045 non-null   object
#  1   AntlerMaleCnt      1052 non-null   int32
#  2   AntlerlessMaleCnt  1052 non-null   int64
#  3   FemaleCnt          1052 non-null   int32
#  4   TotalHarvestCount  1052 non-null   int32
#  5   Season             1052 non-null   object
# dtypes: int32(3), int64(1), object(2)
# memory usage: 45.2+ KB

# %% [markdown]
# # Load in other data sets for Tennessee Deer Registry, CWD Data, and license information.

# %%
tn_registry = pd.read_csv("../Data/tennessee_deer_registry.csv")
tn_registry.head()
# Out:
#   Last Name First Name    Score     Type        Weapon Harvest Date   County
# 0    Tucker    Stephen  315 1/8  Non-Typ  Muzzleloader    11/5/2016   Sumner
# 1   Wachtel   David K.  244 3/8   Nontyp  Muzzleloader    11/6/2000   Sumner
# 2   Samples     Justin  232 7/8   Nontyp           Gun    12/1/2001  Haywood
# 3    Cannon     Nelson  227 1/4   Nontyp           Gun    11/8/2007  Haywood
# 4    Fuller     Luther  223       Nontyp           Gun   11/23/1984  Hawkins

# %%
cwd = pd.read_excel("../Data/cwd_test_results.xlsx")

# %%
cwd.head()
# Out:
#    Confirmation Number Date of Harvest County of Harvest        Result
# 0             24388736      2018-11-18           Carroll  Not Detected
# 1             24912940      2021-11-07          Sullivan  Not Detected
# 2             24922449      2021-11-13           Chester  Not Detected
# 3             24944754      2021-11-21           Overton  Not Detected
# 4             25047367      2022-08-28            Hardin  Not Detected

# %%
license = pd.read_csv("../Data/table_a_license_hol.csv")

# %%
license.head()
# Out:
#             Year Place Name  Paid Hunting License Holders  \
# 0  1/1/2024 0:00  TENNESSEE                        844172
# 1  1/1/2023 0:00  TENNESSEE                        728759
# 2  1/1/2022 0:00  TENNESSEE                        709914
# 3  1/1/2021 0:00  TENNESSEE                        694458
# 4  1/1/2020 0:00  TENNESSEE                        684364
#
#    Resident Hunting Licenses, Tags, Permits and Stamps  \
# 0                                          1267492.0
# 1                                           895058.0
# 2                                           756603.0
# 3                                           722305.0
# 4                                           646743.0
#
#    Non-Resident Hunting Licenses, Tags, Permits and Stamps  \
# 0                                           171230.0
# 1                                           159023.0
# 2                                            45259.0
# 3                                            66774.0
# ...

# %% [markdown]
# # Explore deer harvest data.

# %%
deer_harvest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1052 entries, 0 to 94
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   County             1045 non-null   object
#  1   AntlerMaleCnt      1052 non-null   int32
#  2   AntlerlessMaleCnt  1052 non-null   int64
#  3   FemaleCnt          1052 non-null   int32
#  4   TotalHarvestCount  1052 non-null   int32
#  5   Season             1052 non-null   object
# dtypes: int32(3), int64(1), object(2)
# memory usage: 45.2+ KB

# %%
deer_harvest.groupby('Season').value_counts()
# Out:
# Season  County    AntlerMaleCnt  AntlerlessMaleCnt  FemaleCnt  TotalHarvestCount
# 2013    Anderson  0              58                 496        1112                 1
#         Bedford   0              74                 930        2021                 1
#         Hancock   0              27                 294        731                  1
#         Hardin    0              171                1382       3011                 1
#         Hawkins   0              69                 946        2377                 1
#                                                                                    ..
# 2023    Maury     1736           172                1383       3306                 1
#         McMinn    1042           105                728        1887                 1
#         McNairy   1202           110                1043       2365                 1
#         Meigs     675            90                 578        1350                 1
# ...

# %%
#looking at total harvest per year.
total_harvest_by_year = deer_harvest.groupby('Season')['TotalHarvestCount'].sum().reset_index()
total_harvest_by_year
# Out:
#    Season  TotalHarvestCount
# 0    2013             168522
# 1    2014             165033
# 2    2015             167498
# 3    2016             157714
# 4    2017             146628
# 5    2018             147712
# 6    2019             135184
# 7    2020             160295
# 8    2021             132311
# 9    2022             163323
# 10   2023             152875

# %%
sns.lineplot(data=total_harvest_by_year, x="Season", y="TotalHarvestCount")
plt.ylabel('Total Harvest')
plt.title('Deer Harvest by Year')
plt.show()
# Out:
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # What happened between 2019 and 2023?

# %%
dh_2019_to_2023 = deer_harvest[deer_harvest['Season']>='2019']
dh_2019_to_2023
# Out:
#         County  AntlerMaleCnt  AntlerlessMaleCnt  FemaleCnt  \
# 0     Anderson            475                 49        316
# 1      Bedford            874                 70        670
# 2       Benton            733                123        695
# 3      Bledsoe            524                 54        361
# 4       Blount            460                 19        147
# ..         ...            ...                ...        ...
# 90       Wayne           1077                148        901
# 91     Weakley           1391                140       1283
# 92       White            741                 51        473
# 93  Williamson            825                 71        538
# 94      Wilson           1605                150       1100
#
#     TotalHarvestCount Season
# 0                 840   2019
# 1                1614   2019
# 2                1551   2019
# 3                 939   2019
# 4                 626   2019
# ..                ...    ...
# 90               2134   2023
# ...

# %%
county_counts_2019_to_2023 = dh_2019_to_2023.groupby(['County','Season'])['TotalHarvestCount'].value_counts().reset_index()
county_counts_2019_to_2023
# Out:
#        County Season  TotalHarvestCount  count
# 0    Anderson   2019                840      1
# 1    Anderson   2020                855      1
# 2    Anderson   2021                788      1
# 3    Anderson   2022                945      1
# 4    Anderson   2023                931      1
# ..        ...    ...                ...    ...
# 470    Wilson   2019               2354      1
# 471    Wilson   2020               2849      1
# 472    Wilson   2021               2540      1
# 473    Wilson   2022               2956      1
# 474    Wilson   2023               2871      1
#
# [475 rows x 4 columns]

# %%
county_counts_2019_to_2023['Change'] = county_counts_2019_to_2023.groupby('County')['TotalHarvestCount'].pct_change() * 100

# %%
county_counts_2019_to_2023.head(20)
# Out:
#       County Season  TotalHarvestCount  count     Change
# 0   Anderson   2019                840      1        NaN
# 1   Anderson   2020                855      1   1.785714
# 2   Anderson   2021                788      1  -7.836257
# 3   Anderson   2022                945      1  19.923858
# 4   Anderson   2023                931      1  -1.481481
# 5    Bedford   2019               1614      1        NaN
# 6    Bedford   2020               1844      1  14.250310
# 7    Bedford   2021               1455      1 -21.095445
# 8    Bedford   2022               1911      1  31.340206
# 9    Bedford   2023               1871      1  -2.093145
# 10    Benton   2019               1551      1        NaN
# 11    Benton   2020               1880      1  21.212121
# 12    Benton   2021               1470      1 -21.808511
# 13    Benton   2022               2230      1  51.700680
# 14    Benton   2023               1458      1 -34.618834
# ...

# %%
pct_change_2022 = county_counts_2019_to_2023[county_counts_2019_to_2023['Season']=='2022']
pct_change_2022
# Out:
#          County Season  TotalHarvestCount  count     Change
# 3      Anderson   2022                945      1  19.923858
# 8       Bedford   2022               1911      1  31.340206
# 13       Benton   2022               2230      1  51.700680
# 18      Bledsoe   2022                967      1   5.337691
# 23       Blount   2022                729      1  -1.884253
# ..          ...    ...                ...    ...        ...
# 453       Wayne   2022               3212      1  36.506587
# 458     Weakley   2022               2650      1  34.997453
# 463       White   2022               1165      1  13.106796
# 468  Williamson   2022               1549      1  12.246377
# 473      Wilson   2022               2956      1  16.377953
#
# [95 rows x 5 columns]

# %%
pct_change_2022.sort_values('Change', ascending=False).head(20)
# Out:
#          County Season  TotalHarvestCount  count     Change
# 338       Perry   2022               2003      1  80.776173
# 253       Lewis   2022                996      1  65.723794
# 298     McNairy   2022               3059      1  64.197531
# 193   Henderson   2022               2448      1  58.754864
# 213   Humphreys   2022               2538      1  54.661792
# 248    Lawrence   2022               3975      1  51.891479
# 13       Benton   2022               2230      1  51.700680
# 108     Dickson   2022               2853      1  46.082949
# 58      Chester   2022               1366      1  45.319149
# 53     Cheatham   2022               1660      1  44.097222
# 208     Houston   2022               1172      1  43.980344
# 243  Lauderdale   2022               1331      1  41.145281
# 203     Hickman   2022               2393      1  39.859731
# 103     Decatur   2022               1602      1  38.222606
# 198       Henry   2022               3221      1  36.947279
# ...

# %% [markdown]
# ### Unit CWD includes Chester, Crockett, Fayette, Gibson, Hardeman, Haywood, Henderson, Madison, McNairy, Lauderdale, Shelby, and Tipton counties.

# %% [markdown]
# ### create county unit lists

# %%
#create CWD county list.
cwd_counties = ['Chester','Crockett','Fayette','Gibson','Hardeman','Haywood','Henderson','Madison','McNairy','Lauderdale','Shelby','Tipton']
cwd_counties
# Out:
# ['Chester',
#  'Crockett',
#  'Fayette',
#  'Gibson',
#  'Hardeman',
#  'Haywood',
#  'Henderson',
#  'Madison',
#  'McNairy',
#  'Lauderdale',
#  'Shelby',
#  'Tipton']

# %%
unit_a_string = "Bradley Carter Hamilton Hawkins Johnson Knox Loudon Marion McMinn Meigs Rhea Roane Sullivan"
unit_a = unit_a_string.split()
unit_a
# Out:
# ['Bradley',
#  'Carter',
#  'Hamilton',
#  'Hawkins',
#  'Johnson',
#  'Knox',
#  'Loudon',
#  'Marion',
#  'McMinn',
#  'Meigs',
#  'Rhea',
#  'Roane',
#  'Sullivan']

# %%
unit_b_string =  "Anderson, Bledsoe, Campbell, Claiborne, Clay, Cumberland, DeKalb, Fentress, Grundy, Hancock, Jackson, Morgan, Overton, Pickett, Putnam, Scott, Sequatchie, Van Buren, Warren, White"
unit_b_string = unit_b_string.replace(',','')
unit_b = unit_b_string.split()
unit_b
# Out:
# ['Anderson',
#  'Bledsoe',
#  'Campbell',
#  'Claiborne',
#  'Clay',
#  'Cumberland',
#  'DeKalb',
#  'Fentress',
#  'Grundy',
#  'Hancock',
#  'Jackson',
#  'Morgan',
#  'Overton',
#  'Pickett',
#  'Putnam',
#  'Scott',
#  'Sequatchie',
#  'Van',
#  'Buren',
#  'Warren',
#  'White']

# %%
unit_c_string = "Cocke, Grainger, Greene, Hamblen, Jefferson, Unicoi, Union, Washington"
unit_c_string = unit_c_string.replace(',','')
unit_c = unit_c_string.split()
unit_c
# Out:
# ['Cocke',
#  'Grainger',
#  'Greene',
#  'Hamblen',
#  'Jefferson',
#  'Unicoi',
#  'Union',
#  'Washington']

# %%
unit_d_string = "Blount, Monroe, Polk, Sevier"
unit_d_string = unit_d_string.replace(',','')
unit_d = unit_d_string.split()
unit_d
# Out:
# ['Blount', 'Monroe', 'Polk', 'Sevier']

# %%
unit_l_string = "Bedford, Benton, Cannon, Carroll, Cheatham, Coffee, Davidson, Decatur, Dickson, Dyer, Franklin, Giles, Hardin, Henry, Hickman, Houston, Humphreys, Lake, Lawrence, Lewis, Lincoln, Macon, Marshall, Maury, Montgomery, Moore, Obion, Perry, Robertson, Rutherford, Smith, Stewart, Sumner, Trousdale, Wayne, Weakley, Williamson, Wilson"
unit_l_string = unit_l_string.replace(',','')
unit_l = unit_l_string.split()
unit_l
# Out:
# ['Bedford',
#  'Benton',
#  'Cannon',
#  'Carroll',
#  'Cheatham',
#  'Coffee',
#  'Davidson',
#  'Decatur',
#  'Dickson',
#  'Dyer',
#  'Franklin',
#  'Giles',
#  'Hardin',
#  'Henry',
#  'Hickman',
#  'Houston',
#  'Humphreys',
#  'Lake',
#  'Lawrence',
#  'Lewis',
#  'Lincoln',
#  'Macon',
#  'Marshall',
#  'Maury',
#  'Montgomery',
#  'Moore',
#  'Obion',
#  'Perry',
#  'Robertson',
#  'Rutherford',
#  'Smith',
#  'Stewart',
#  'Sumner',
#  'Trousdale',
#  'Wayne',
#  'Weakley',
#  'Williamson',
#  'Wilson']

# %%
#compare difference 
harvest_difference_2021_2022 = county_counts_2019_to_2023[(county_counts_2019_to_2023['Season']>='2021') & (county_counts_2019_to_2023['Season']<'2023')]
harvest_difference_2021_2022 = harvest_difference_2021_2022.drop('Change',axis=1)
harvest_difference_2021_2022['Diff'] = harvest_difference_2021_2022.groupby('County')['TotalHarvestCount'].diff().fillna(0)
harvest_difference_2021_2022.sort_values('Diff',ascending=False)
# Out:
#         County Season  TotalHarvestCount  count    Diff
# 248   Lawrence   2022               3975      1  1358.0
# 298    McNairy   2022               3059      1  1196.0
# 193  Henderson   2022               2448      1   906.0
# 108    Dickson   2022               2853      1   900.0
# 213  Humphreys   2022               2538      1   897.0
# ..         ...    ...                ...    ...     ...
# 228    Johnson   2022                989      1   -13.0
# 23      Blount   2022                729      1   -14.0
# 168    Hancock   2022                490      1   -19.0
# 433      Union   2022                493      1   -22.0
# 348       Polk   2022                298      1   -46.0
#
# [190 rows x 5 columns]

# %%
#get count of increase harvest in CWD counties.
Counties_2022_Diff = harvest_difference_2021_2022[harvest_difference_2021_2022['Season']>'2021']
CWD_Counties_2022_Diff = Counties_2022_Diff[Counties_2022_Diff['County'].isin(cwd_counties)]
CWD_Counties_2022_Diff['Diff'].sum()
# Out:
# 5247.0

# %%
unit_a_diff = Counties_2022_Diff[Counties_2022_Diff['County'].isin(unit_a)]
unit_a_diff['Diff'].sum()
# Out:
# 2679.0

# %%
unit_b_diff = Counties_2022_Diff[Counties_2022_Diff['County'].isin(unit_b)]
unit_b_diff['Diff'].sum()
# Out:
# 2777.0

# %%
unit_c_diff = Counties_2022_Diff[Counties_2022_Diff['County'].isin(unit_c)]
unit_c_diff['Diff'].sum()
# Out:
# 200.0

# %%
unit_d_diff = Counties_2022_Diff[Counties_2022_Diff['County'].isin(unit_d)]
unit_d_diff['Diff'].sum()
# Out:
# 42.0

# %%
unit_l_diff = Counties_2022_Diff[Counties_2022_Diff['County'].isin(unit_l)]
unit_l_diff['Diff'].sum()
# Out:
# 19956.0

# %%
#df[pd.DataFrame(df.species.tolist()).isin(selection).any(1).values]

# %%
sns.lineplot(data=county_counts_2019_to_2023, x="Season", y="TotalHarvestCount", hue='County')
plt.legend(title='County')
#sns.move_legend(type_lineplot, "upper left", bbox_to_anchor=(1, 1))
plt.xlabel('Season')
plt.ylabel('Total Harvest')
plt.title('Deer Harvest by County')
plt.show()
# Out:
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#looking at count of each type of harvest by year.
count_type_by_year = deer_harvest.groupby('Season').agg({'AntlerMaleCnt':'sum',
                                    'AntlerlessMaleCnt':'sum',
                                    'FemaleCnt':'sum',
                                    'TotalHarvestCount':'sum'}).reset_index()
count_type_by_year
# Out:
#    Season  AntlerMaleCnt  AntlerlessMaleCnt  FemaleCnt  TotalHarvestCount
# 0    2013              1               8558      73906             168522
# 1    2014              1               8271      69476             165033
# 2    2015              0               8405      77135             167498
# 3    2016              0               4848      71698             157714
# 4    2017              6               4430      63434             146628
# 5    2018          73432              10887      63281             147712
# 6    2019          71889               7220      56036             135184
# 7    2020          86404               8842      65026             160295
# 8    2021          74547               7118      50633             132311
# 9    2022          86332               8812      68141             163323
# 10   2023          84433               7163      60550             152875

# %%
#correct for missing values in AntlerMaleCnt column. Total harvest did not include those numbers. 
#Is calculated by subtracting AnterlessMaleCnt and FemaleCnt from Total.
count_type_by_year.at[0,'AntlerMaleCnt']= (168522-(8558+73906))
count_type_by_year.at[1,'AntlerMaleCnt']= (165033-(8271+69476))
count_type_by_year.at[2,'AntlerMaleCnt']= (167498-(8405+77135))
count_type_by_year.at[3,'AntlerMaleCnt']= (157714-(4848+71698))
count_type_by_year.at[4,'AntlerMaleCnt']= (146628-(4430+63434))
count_type_by_year
# Out:
#    Season  AntlerMaleCnt  AntlerlessMaleCnt  FemaleCnt  TotalHarvestCount
# 0    2013          86058               8558      73906             168522
# 1    2014          87286               8271      69476             165033
# 2    2015          81958               8405      77135             167498
# 3    2016          81168               4848      71698             157714
# 4    2017          78764               4430      63434             146628
# 5    2018          73432              10887      63281             147712
# 6    2019          71889               7220      56036             135184
# 7    2020          86404               8842      65026             160295
# 8    2021          74547               7118      50633             132311
# 9    2022          86332               8812      68141             163323
# 10   2023          84433               7163      60550             152875

# %%
#show count of type by year in long df form.
ctby_melt = count_type_by_year.melt('Season', var_name='cols', value_name='vals')
ctby_melt.head()
# Out:
#   Season           cols   vals
# 0   2013  AntlerMaleCnt  86058
# 1   2014  AntlerMaleCnt  87286
# 2   2015  AntlerMaleCnt  81958
# 3   2016  AntlerMaleCnt  81168
# 4   2017  AntlerMaleCnt  78764

# %%
ctby_melt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Season  44 non-null     object
#  1   cols    44 non-null     object
#  2   vals    44 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.2+ KB

# %%
ctby_melt
# Out:
#    Season               cols    vals
# 0    2013      AntlerMaleCnt   86058
# 1    2014      AntlerMaleCnt   87286
# 2    2015      AntlerMaleCnt   81958
# 3    2016      AntlerMaleCnt   81168
# 4    2017      AntlerMaleCnt   78764
# 5    2018      AntlerMaleCnt   73432
# 6    2019      AntlerMaleCnt   71889
# 7    2020      AntlerMaleCnt   86404
# 8    2021      AntlerMaleCnt   74547
# 9    2022      AntlerMaleCnt   86332
# 10   2023      AntlerMaleCnt   84433
# 11   2013  AntlerlessMaleCnt    8558
# 12   2014  AntlerlessMaleCnt    8271
# 13   2015  AntlerlessMaleCnt    8405
# 14   2016  AntlerlessMaleCnt    4848
# 15   2017  AntlerlessMaleCnt    4430
# 16   2018  AntlerlessMaleCnt   10887
# 17   2019  AntlerlessMaleCnt    7220
# 18   2020  AntlerlessMaleCnt    8842
# 19   2021  AntlerlessMaleCnt    7118
# 20   2022  AntlerlessMaleCnt    8812
# 21   2023  AntlerlessMaleCnt    7163
# 22   2013          FemaleCnt   73906
# 23   2014          FemaleCnt   69476
# ...

# %%
type_lineplot = sns.lineplot(data=ctby_melt, x="Season", y="vals", hue='cols')
plt.legend(title='Type')
sns.move_legend(type_lineplot, "upper left", bbox_to_anchor=(1, 1))
plt.xlabel('Year')
plt.ylabel('Total Harvest')
plt.title('Deer Harvest Type Per Season')
plt.show()
# Out:
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
count_type_by_year2 = count_type_by_year.drop('TotalHarvestCount', axis=1)
type_bar = count_type_by_year2.plot.bar(stacked=True)
plt.xlabel('Season')
plt.legend(title='Type')
sns.move_legend(type_bar, loc="upper left", bbox_to_anchor=(1, 1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[226], line 4
#       2 type_bar = count_type_by_year2.plot.bar(stacked=True)
#       3 plt.xlabel('Season')
# ----> 4 type_bar.set_xticklabels(years)
#       5 plt.legend(title='Type')
#       6 sns.move_legend(type_bar, loc="upper left", bbox_to_anchor=(1, 1))
#
# NameError: name 'years' is not defined

# %% [markdown]
# # Explore CWD data.

# %%
cwd.head()
# Out:
#    Confirmation Number Date of Harvest County of Harvest        Result
# 0             24388736      2018-11-18           Carroll  Not Detected
# 1             24912940      2021-11-07          Sullivan  Not Detected
# 2             24922449      2021-11-13           Chester  Not Detected
# 3             24944754      2021-11-21           Overton  Not Detected
# 4             25047367      2022-08-28            Hardin  Not Detected

# %%
cwd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16016 entries, 0 to 16015
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Confirmation Number  16016 non-null  int64
#  1   Date of Harvest      16016 non-null  datetime64[ns]
#  2   County of Harvest    16016 non-null  object
#  3   Result               16016 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 500.6+ KB

# %%
#extract year from date of harvest
cwd['Season'] = cwd['Date of Harvest'].dt.year
cwd.head()
# Out:
#    Confirmation Number Date of Harvest County of Harvest        Result  Season
# 0             24388736      2018-11-18           Carroll  Not Detected    2018
# 1             24912940      2021-11-07          Sullivan  Not Detected    2021
# 2             24922449      2021-11-13           Chester  Not Detected    2021
# 3             24944754      2021-11-21           Overton  Not Detected    2021
# 4             25047367      2022-08-28            Hardin  Not Detected    2022

# %%
#Result counts by year.
cwd_count_by_year = cwd.groupby('Season')['Result'].value_counts().reset_index()
cwd_count_by_year
# Out:
#     Season        Result  count
# 0     2018  Not Detected      1
# 1     2021  Not Detected      3
# 2     2022  Not Detected     50
# 3     2022      Positive      1
# 4     2023  Not Detected  13538
# 5     2023      Positive    644
# 6     2023       Pending     39
# 7     2023    Untestable     17
# 8     2024  Not Detected   1638
# 9     2024      Positive     80
# 10    2024       Pending      5

# %%
cwd[cwd['Season']==2020]
# Out:
# Empty DataFrame
# Columns: [Confirmation Number, Date of Harvest, County of Harvest, Result, Season]
# Index: []

# %%
#CWD not present until 2018.
cwd['Season'].value_counts().sort_values()
# Out:
# Season
# 2018        1
# 2021        3
# 2022       51
# 2024     1723
# 2023    14238
# Name: count, dtype: int64

# %%
type_lineplot = sns.barplot(data=cwd_count_by_year, x="Season", y="count", hue='Result')
plt.legend(title='CWD Results')
sns.move_legend(type_lineplot, "upper left", bbox_to_anchor=(1, 1))
plt.xlabel('Season Year')
plt.ylabel('Count')
plt.title('CWD Presense')
plt.show()

# %%
cwd_count_by_year.plot.bar()
# Out:
# <Axes: >

# %%
cwd_positive = cwd[cwd['Result']== 'Positive']
cwd_positive.head()
# Out:
#      Confirmation Number Date of Harvest County of Harvest    Result  Season
# 28              25139956      2022-11-26          Hardeman  Positive    2022
# 63              25209621      2023-01-21           Fayette  Positive    2023
# 95              25244946      2023-08-26           Fayette  Positive    2023
# 102             25244994      2023-08-26           Fayette  Positive    2023
# 110             25245067      2023-08-26          Hardeman  Positive    2023

# %%
positive_count = cwd_positive.groupby('Season')['Result'].value_counts().reset_index()
positive_count
# Out:
#    Season    Result  count
# 0    2022  Positive      1
# 1    2023  Positive    644
# 2    2024  Positive     80

# %%
ax = sns.barplot(data=positive_count, x="Season", y="count")
ax.bar_label(ax.containers[0])
plt.ylabel('Count')
plt.title('Positive CWD Detected')

plt.show()

# %%
#count of positive CWD cases by county.
cwd_positive.groupby('County of Harvest')['Result'].value_counts().sort_values(ascending=False).reset_index()
# Out:
#    County of Harvest    Result  count
# 0            Fayette  Positive    361
# 1           Hardeman  Positive    297
# 2             Shelby  Positive     29
# 3            Madison  Positive     12
# 4            Haywood  Positive     10
# 5            Chester  Positive      3
# 6             Hardin  Positive      3
# 7            McNairy  Positive      2
# 8             Tipton  Positive      2
# 9           Crockett  Positive      1
# 10            Gibson  Positive      1
# 11             Henry  Positive      1
# 12             Lewis  Positive      1
# 13          crockett  Positive      1
# 14           fayette  Positive      1

# %% [markdown]
# # Explore TN Deer Registry

# %%
tn_registry.head()
# Out:
#   Last Name First Name    Score     Type        Weapon Harvest Date   County
# 0    Tucker    Stephen  315 1/8  Non-Typ  Muzzleloader    11/5/2016   Sumner
# 1   Wachtel   David K.  244 3/8   Nontyp  Muzzleloader    11/6/2000   Sumner
# 2   Samples     Justin  232 7/8   Nontyp           Gun    12/1/2001  Haywood
# 3    Cannon     Nelson  227 1/4   Nontyp           Gun    11/8/2007  Haywood
# 4    Fuller     Luther  223       Nontyp           Gun   11/23/1984  Hawkins

# %%
tn_registry.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3197 entries, 0 to 3196
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Last Name     3197 non-null   object
#  1   First Name    3197 non-null   object
#  2   Score         3197 non-null   object
#  3   Type          3197 non-null   object
#  4   Weapon        3197 non-null   object
#  5   Harvest Date  3197 non-null   object
#  6   County        3197 non-null   object
# dtypes: object(7)
# memory usage: 175.0+ KB

# %% [markdown]
# ### Tried to convert to datetime but received error at location 2389.

# %%
tn_registry.loc[2389]
# Out:
# Last Name         Barefoot
# First Name           Jason
# Score              138 1/4
# Type                   Typ
# Weapon                 Bow
# Harvest Date     9/28/8017
# County          Montgomery
# Name: 2389, dtype: object

# %%
#correct year for entry
tn_registry.at[2389,'Harvest Date']= '9/28/2017'

# %% [markdown]
# ### Tried again to format to datetime and received erro at location 2946.

# %%
tn_registry[tn_registry['Harvest Date']=='0015-11-03']
# Out:
#      Last Name First Name    Score Type Weapon Harvest Date      County
# 2946    Powell       Matt  123 1/8  Typ    Bow   0015-11-03  Montgomery

# %%
tn_registry.loc[2946]
# Out:
# Last Name           Powell
# First Name            Matt
# Score              123 1/8
# Type                   Typ
# Weapon                 Bow
# Harvest Date    0015-11-03
# County          Montgomery
# Name: 2946, dtype: object

# %%
tn_registry.at[2946,'Harvest Date']= '11/3/2015'

# %% [markdown]
# ### Tried again and was successful.

# %%
tn_registry['Harvest Date'] = pd.to_datetime(tn_registry['Harvest Date'])

# %%
tn_registry.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3197 entries, 0 to 3196
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Last Name     3197 non-null   object
#  1   First Name    3197 non-null   object
#  2   Score         3197 non-null   object
#  3   Type          3197 non-null   object
#  4   Weapon        3197 non-null   object
#  5   Harvest Date  3197 non-null   datetime64[ns]
#  6   County        3197 non-null   object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 175.0+ KB

# %%
tn_registry['Season'] = tn_registry['Harvest Date'].dt.year
tn_registry.head()
# Out:
#   Last Name First Name    Score     Type        Weapon Harvest Date   County  \
# 0    Tucker    Stephen  315 1/8  Non-Typ  Muzzleloader   2016-11-05   Sumner
# 1   Wachtel   David K.  244 3/8   Nontyp  Muzzleloader   2000-11-06   Sumner
# 2   Samples     Justin  232 7/8   Nontyp           Gun   2001-12-01  Haywood
# 3    Cannon     Nelson  227 1/4   Nontyp           Gun   2007-11-08  Haywood
# 4    Fuller     Luther  223       Nontyp           Gun   1984-11-23  Hawkins
#
#    Season
# 0    2016
# 1    2000
# 2    2001
# 3    2007
# 4    1984

# %%
#looking at aggregates.
tn_registry['Season'].agg({'min','max','mean','median'})
# Out:
# median    2002.000000
# min       1915.000000
# max       2024.000000
# mean      2001.240851
# Name: Season, dtype: float64

# %%
registry_count_by_year = tn_registry.groupby('Season').size().reset_index(name='count')
registry_count_by_year.nsmallest(10,'count')
# Out:
#     Season  count
# 0     1915      1
# 1     1940      1
# 2     1955      1
# 4     1957      1
# 7     1960      1
# 8     1961      1
# 71    2024      1
# 12    1965      2
# 3     1956      3
# 6     1959      3

# %%
#plotting record counts for all years.
sns.lineplot(data=registry_count_by_year, x="Season", y="count")
plt.ylabel('Total Records')
plt.title('Record Harvest by Season')
sns.set(rc={"figure.figsize":(12, 6)})
plt.show()
# Out:
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
record_method_by_year = tn_registry.groupby(['Season','Weapon']).size().reset_index(name='count')
record_method_by_year
# Out:
#      Season        Weapon  count
# 0      1915           Gun      1
# 1      1940           Gun      1
# 2      1955           Gun      1
# 3      1956           Gun      3
# 4      1957           Gun      1
# ..      ...           ...    ...
# 149    2022  Muzzleloader     18
# 150    2023           Bow     11
# 151    2023           Gun     12
# 152    2023  Muzzleloader      6
# 153    2024           Gun      1
#
# [154 rows x 3 columns]

# %%
method_lineplot = sns.lineplot(data=record_method_by_year, x="Season", y="count", hue='Weapon')
plt.legend(title='Method')
sns.move_legend(type_lineplot, "upper left", bbox_to_anchor=(1, 1))
plt.xlabel('Season')
plt.ylabel('Total by Method')
plt.title('Record Harvest Methods')
plt.show()
# Out:
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
record_method_2013_to_2023 = record_method_by_year[(record_method_by_year['Season']>=2013) & (record_method_by_year['Season'] < 2024)]
record_method_2013_to_2023
# Out:
#      Season        Weapon  count
# 120    2013           Bow     21
# 121    2013           Gun     21
# 122    2013  Muzzleloader     28
# 123    2014           Bow     22
# 124    2014           Gun     19
# 125    2014  Muzzleloader     23
# 126    2015           Bow     33
# 127    2015           Gun     32
# 128    2015  Muzzleloader     44
# 129    2016           Bow     28
# 130    2016           Gun     24
# 131    2016  Muzzleloader     34
# 132    2017           Bow     23
# 133    2017           Gun     29
# 134    2017  Muzzleloader     28
# 135    2018           Bow     35
# 136    2018           Gun     27
# 137    2018  Muzzleloader     26
# 138    2019           Bow      9
# 139    2019           Gun     15
# 140    2019  Muzzleloader     35
# 141    2020           Bow     32
# 142    2020           Gun     33
# 143    2020  Muzzleloader     27
# 144    2021           Bow     17
# 145    2021           Gun     26
# 146    2021  Muzzleloader     30
# ...

# %%
method_2013_to_2023_lineplot = sns.lineplot(data=record_method_2013_to_2023, x="Season", y="count", hue='Weapon')
plt.legend(title='Method')
sns.move_legend(type_lineplot, "upper left", bbox_to_anchor=(1, 1))
plt.xlabel('Season')
plt.ylabel('Total by Method')
plt.title('Record Harvest Methods 2013 to 2023')
plt.show()
# Out:
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
method_barplot = sns.barplot(data=record_method_2013_to_2023, x="Season", y="count", hue='Weapon')
plt.legend(title='Method')
sns.move_legend(method_barplot, "upper left", bbox_to_anchor=(1, 1))
plt.xlabel('Season')
plt.ylabel('Count')
plt.title('Methods by Season')
plt.show()

# %% [markdown]
# ### Check to see if correlation between record entries and total harvest numbers. Need to merge df's to check.

# %% [markdown]
# #### total_harvest_by_year
# #### registry_count_by_year (need to subset for 2013 to 2023)

# %%
rcby_2013_to_2023 = registry_count_by_year[(registry_count_by_year['Season']>=2013) & (registry_count_by_year['Season']<2024)]
rcby_2013_to_2023.rename(columns = {'count':'RecordCount'}, inplace = True)
rcby_2013_to_2023
# Out:
# C:\Users\mcnut\AppData\Local\Temp\ipykernel_7856\2729216242.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rcby_2013_to_2023.rename(columns = {'count':'RecordCount'}, inplace = True)
#     Season  RecordCount
# 60    2013           70
# 61    2014           64
# 62    2015          109
# 63    2016           86
# 64    2017           80
# 65    2018           88
# 66    2019           59
# 67    2020           92
# 68    2021           73
# 69    2022           54
# 70    2023           29

# %%
total_harvest_by_year
# Out:
#    Season  TotalHarvestCount
# 0    2013             168522
# 1    2014             165033
# 2    2015             167498
# 3    2016             157714
# 4    2017             146628
# 5    2018             147712
# 6    2019             135184
# 7    2020             160295
# 8    2021             132311
# 9    2022             163323
# 10   2023             152875

# %%
total_harvest_by_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Season             11 non-null     object
#  1   TotalHarvestCount  11 non-null     int32
# dtypes: int32(1), object(1)
# memory usage: 264.0+ bytes

# %%
total_harvest_by_year['Season'] = total_harvest_by_year['Season'].astype(int)

# %%
#merge the two df's
records_and_total_harvest = pd.merge(total_harvest_by_year, rcby_2013_to_2023, how="inner", on=["Season"])
records_and_total_harvest
# Out:
#     Season  TotalHarvestCount  RecordCount
# 0     2013             168522           70
# 1     2014             165033           64
# 2     2015             167498          109
# 3     2016             157714           86
# 4     2017             146628           80
# 5     2018             147712           88
# 6     2019             135184           59
# 7     2020             160295           92
# 8     2021             132311           73
# 9     2022             163323           54
# 10    2023             152875           29

# %%
records_and_total_harvest.corr()
# Out:
#                      Season  TotalHarvestCount  RecordCount
# Season             1.000000          -0.473263    -0.504376
# TotalHarvestCount -0.473263           1.000000     0.184369
# RecordCount       -0.504376           0.184369     1.000000

# %%
records_and_total_harvest['TotalHarvestCount'].corr(records_and_total_harvest['RecordCount'])
# Out:
# 0.1843694015362503

# %%
sns.regplot(data=records_and_total_harvest, x='TotalHarvestCount', y='RecordCount')
plt.xlabel("Total Harvest Count")
plt.ylabel("Record Count")
plt.title("Correlation")
plt.show()

# %% [markdown]
# ### Very weak correlation

# %% [markdown]
# # Next checking to see if there is a correlation between total harvest count and method of take.

# %%
record_method_2013_to_2023.head()
# Out:
#      Season        Weapon  count
# 120    2013           Bow     21
# 121    2013           Gun     21
# 122    2013  Muzzleloader     28
# 123    2014           Bow     22
# 124    2014           Gun     19

# %%
total_harvest_by_year.head()
# Out:
#    Season  TotalHarvestCount
# 0    2013             168522
# 1    2014             165033
# 2    2015             167498
# 3    2016             157714
# 4    2017             146628

# %%
methods_and_total_harvest = pd.merge(total_harvest_by_year, record_method_2013_to_2023, how="outer", on=["Season"])
methods_and_total_harvest
# Out:
#     Season  TotalHarvestCount        Weapon  count
# 0     2013             168522           Bow     21
# 1     2013             168522           Gun     21
# 2     2013             168522  Muzzleloader     28
# 3     2014             165033           Bow     22
# 4     2014             165033           Gun     19
# 5     2014             165033  Muzzleloader     23
# 6     2015             167498           Bow     33
# 7     2015             167498           Gun     32
# 8     2015             167498  Muzzleloader     44
# 9     2016             157714           Bow     28
# 10    2016             157714           Gun     24
# 11    2016             157714  Muzzleloader     34
# 12    2017             146628           Bow     23
# 13    2017             146628           Gun     29
# 14    2017             146628  Muzzleloader     28
# 15    2018             147712           Bow     35
# 16    2018             147712           Gun     27
# ...

# %%
sns.scatterplot(data=methods_and_total_harvest, x='count', y='TotalHarvestCount', hue='Weapon')
plt.xlabel("Method Count")
plt.ylabel("Total Harvest Count")
plt.title("Correlation")
plt.show()

# %% [markdown]
# # Exploring License Sales Data

# %%
license.head()
# Out:
#             Year Place Name  Paid Hunting License Holders  \
# 0  1/1/2024 0:00  TENNESSEE                        844172
# 1  1/1/2023 0:00  TENNESSEE                        728759
# 2  1/1/2022 0:00  TENNESSEE                        709914
# 3  1/1/2021 0:00  TENNESSEE                        694458
# 4  1/1/2020 0:00  TENNESSEE                        684364
#
#    Resident Hunting Licenses, Tags, Permits and Stamps  \
# 0                                          1267492.0
# 1                                           895058.0
# 2                                           756603.0
# 3                                           722305.0
# 4                                           646743.0
#
#    Non-Resident Hunting Licenses, Tags, Permits and Stamps  \
# 0                                           171230.0
# 1                                           159023.0
# 2                                            45259.0
# 3                                            66774.0
# ...

# %% [markdown]
# ### Paid Hunting License Holders is the number of people who paid for a license to hunt in TN that year (resident and non-resident). Resident and Non-Resident Hunting Licenses, Tags, Permits, and Stamps shows sum of all types of licenses, tags, permits, and stamps (there are different types based on game species). For example, someone can buy a hunt/fish license but not be eligible to duck hunt. That requires additional permits and stamps.

# %%
license.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 8 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Year                                                            67 non-null     object
#  1   Place Name                                                      67 non-null     object
#  2   Paid Hunting License Holders                                    67 non-null     int64
#  3   Resident Hunting Licenses, Tags, Permits and Stamps             60 non-null     float64
#  4   Non-Resident Hunting Licenses, Tags, Permits and Stamps         60 non-null     float64
#  5   Gross Cost - Hunting Licenses                                   60 non-null     float64
#  6   Cost - Resident Hunting Licenses,
# Tags, Permits and Stamps      47 non-null     float64
# ...

# %%
license['Paid Hunting License Holders'].agg({'min','max','mean'})
# Out:
# min     366632.000000
# max     844172.000000
# mean    582345.970149
# Name: Paid Hunting License Holders, dtype: float64

# %%
license['Year'] = pd.to_datetime(license['Year'])

# %%
license['Season'] = license['Year'].dt.year

# %%
license.head()
# Out:
#         Year Place Name  Paid Hunting License Holders  \
# 0 2024-01-01  TENNESSEE                        844172
# 1 2023-01-01  TENNESSEE                        728759
# 2 2022-01-01  TENNESSEE                        709914
# 3 2021-01-01  TENNESSEE                        694458
# 4 2020-01-01  TENNESSEE                        684364
#
#    Resident Hunting Licenses, Tags, Permits and Stamps  \
# 0                                          1267492.0
# 1                                           895058.0
# 2                                           756603.0
# 3                                           722305.0
# 4                                           646743.0
#
#    Non-Resident Hunting Licenses, Tags, Permits and Stamps  \
# 0                                           171230.0
# 1                                           159023.0
# 2                                            45259.0
# 3                                            66774.0
# ...

# %%
sns.lineplot(data=license, x="Season", y="Paid Hunting License Holders")
plt.ylabel('Paid Hunting License Holders')
plt.title('License Holders')
plt.show()
# Out:
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### License holder numbers are trending upwards overall. Need to look at 2013 to 2023.

# %%
license_2013_to_2023 = license[license['Season']>=2013]
license_2013_to_2023
# Out:
#          Year Place Name  Paid Hunting License Holders  \
# 0  2024-01-01  TENNESSEE                        844172
# 1  2023-01-01  TENNESSEE                        728759
# 2  2022-01-01  TENNESSEE                        709914
# 3  2021-01-01  TENNESSEE                        694458
# 4  2020-01-01  TENNESSEE                        684364
# 5  2019-01-01  TENNESSEE                        679038
# 6  2018-01-01  TENNESSEE                        700600
# 7  2017-01-01  TENNESSEE                        717256
# 8  2016-01-01  TENNESSEE                        734733
# 9  2015-01-01  TENNESSEE                        727229
# 10 2014-01-01  TENNESSEE                        566507
# 11 2013-01-01  TENNESSEE                        530547
#
#     Resident Hunting Licenses, Tags, Permits and Stamps  \
# 0                                           1267492.0
# 1                                            895058.0
# 2                                            756603.0
# ...

# %%
sns.lineplot(data=license_2013_to_2023, x="Season", y="Paid Hunting License Holders")
plt.ylabel('Paid Hunting License Holders')
plt.title('License Holders 2013 to 2023')
plt.show()
# Out:
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.lineplot(data=license_2013_to_2023, x="Season", y="Resident Hunting Licenses, Tags, Permits and Stamps")
plt.ylabel('Resident Hunting Licenses, Tags, Permits and Stamps')
plt.title('Residents 2013 to 2023')
plt.show()
# Out:
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.lineplot(data=license_2013_to_2023, x="Season", y="Non-Resident Hunting Licenses, Tags, Permits and Stamps")
plt.ylabel('Non-Resident Hunting Licenses, Tags, Permits and Stamps')
plt.title('Non-Residents 2013 to 2023')
plt.show()
# Out:
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
license_counts = license.drop(['Paid Hunting License Holders','Place Name','Year','Gross Cost - Hunting Licenses','Cost - Resident Hunting Licenses,\nTags, Permits and Stamps','Cost - Non-Resident Hunting Licenses,\nTags, Permits and Stamps'],axis=1)
license_counts.head()
# Out:
#    Resident Hunting Licenses, Tags, Permits and Stamps  \
# 0                                          1267492.0
# 1                                           895058.0
# 2                                           756603.0
# 3                                           722305.0
# 4                                           646743.0
#
#    Non-Resident Hunting Licenses, Tags, Permits and Stamps  Season
# 0                                           171230.0          2024
# 1                                           159023.0          2023
# 2                                            45259.0          2022
# 3                                            66774.0          2021
# 4                                            65560.0          2020

# %%
license_counts_melt = license_counts.melt('Season', var_name='cols', value_name='vals')
license_counts_melt.head()
# Out:
#    Season                                               cols       vals
# 0    2024  Resident Hunting Licenses, Tags, Permits and S...  1267492.0
# 1    2023  Resident Hunting Licenses, Tags, Permits and S...   895058.0
# 2    2022  Resident Hunting Licenses, Tags, Permits and S...   756603.0
# 3    2021  Resident Hunting Licenses, Tags, Permits and S...   722305.0
# 4    2020  Resident Hunting Licenses, Tags, Permits and S...   646743.0

# %%
license_counts_lineplot = sns.lineplot(data=license_counts_melt, x="Season", y="vals", hue='cols')
plt.legend(title='Type')
sns.move_legend(type_lineplot, "upper left", bbox_to_anchor=(1, 1))
plt.xlabel('Season')
plt.ylabel('Total License Counts')
plt.title('Resident vs Non-Resident')
plt.show()
# Out:
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
license_counts_melt_2013_to_2023 = license_counts_melt[(license_counts_melt['Season']>=2013) & (license_counts_melt['Season']<2024)]

# %%
license_counts_lineplot2 = sns.lineplot(data=license_counts_melt_2013_to_2023, x="Season", y="vals", hue='cols')
plt.legend(title='Type')
sns.move_legend(type_lineplot, "upper left", bbox_to_anchor=(1, 1))
plt.xlabel('Season')
plt.ylabel('Total License Counts')
plt.title('Resident vs Non-Resident 2013 to 2023')
plt.show()
# Out:
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mcnut\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Find the following through outside resources:
# ### What year was crossbow introduced to archery season?
# ### What year did the buck limit change?
# ### What caused the spike in harvest numbers in 2022 after a dip in 2021?
# ### What year did CWD become prevalent?
# ### Was there an incentive program for CWD harvests?

# %% [markdown]
# # Safe created df's to csv.

# %%
deer_harvest.to_csv(r'C:\Users\mcnut\Documents\DA11\Capstone\Data\deer_harvest_2013_to_2023.csv', index=False)

# %%
license.to_csv(r'C:\Users\mcnut\Documents\DA11\Capstone\Data\license_clean.csv', index=False)
